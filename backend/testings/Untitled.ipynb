# %%
# from deep_sort_realtime.deepsort_tracker import DeepSort
! pip install deep-sort-realtime
! pip install --upgrade x
ultralytics
# Out:
# Requirement already satisfied: deep-sort-realtime in d:\nexus ai\nexus face recognition\virt\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from deep-sort-realtime) (1.26.4)
# Requirement already satisfied: scipy in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from deep-sort-realtime) (1.15.2)
# Requirement already satisfied: opencv-python in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from deep-sort-realtime) (4.10.0.84)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ultralytics in d:\nexus ai\nexus face recognition\virt\lib\site-packages (8.3.116)
# Collecting ultralytics
#   Downloading ultralytics-8.3.124-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: colorama in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\nexus ai\nexus face recognition\virt\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.124-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 11.8 MB/s eta 0:00:00
# Installing collected packages: ultralytics
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.116
#     Uninstalling ultralytics-8.3.116:
#       Successfully uninstalled ultralytics-8.3.116
# Successfully installed ultralytics-8.3.124
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
./virt/Scripts/activate
# Out:
#   Cell In[13], line 1
#     ./virt/Scripts/activate
#     ^
# SyntaxError: invalid syntax

# %%
from deep_sort_realtime.deepsort_tracker import DeepSort
#
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from deep_sort_realtime.deepsort_tracker import DeepSort
#       2 #
#
# ModuleNotFoundError: No module named 'deep_sort_realtime'
